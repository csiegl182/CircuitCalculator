# %% [markdown]
# # Example 12

# %%
from CircuitCalculator.SimpleCircuit.Elements import Schematic, VoltageSource, Resistor, Line, LabelNode, CurrentSource, Ground, Impedance
from CircuitCalculator.SimpleCircuit.DiagramSolution import complex_solution
from CircuitCalculator.Network.NodalAnalysis import nodal_analysis_solver

# %%
with Schematic() as schematic:
    schematic += (U1:=VoltageSource(V=1-2j, name='U1', precision=2).up())
    schematic += Line().right()
    schematic += (Z1:=Impedance(Z=10+10j, name='Z1', precision=2).down())
    schematic += Line().left()
    schematic += Ground()
    schematic += Impedance(Z=20, name='Z2').at(Z1.start).right()
    schematic += Impedance(Z=30, name='Z3').down()
    schematic += Line().left()
    schemdraw_solution = complex_solution(schematic)
    schematic += schemdraw_solution.draw_voltage('Z1', precision=2)
    schematic += schemdraw_solution.draw_current('Z1', precision=2)
    schematic += schemdraw_solution.draw_voltage('Z2', precision=2)
    schematic += schemdraw_solution.draw_voltage('Z3', precision=2)
    schematic += schemdraw_solution.draw_current('Z3', precision=2, end=True)
    schematic += schemdraw_solution.draw_current('U1', precision=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramParser.py:97, in SchematicDiagramParser.translate_elements.<locals>.translate(element)
#      96 try:
# ---> 97     return translator_map[type(element)](element, tuple(map(self._get_node_index, elm.get_nodes(element))))
#      98 except KeyError:
#
# KeyError: <class 'CircuitCalculator.SimpleCircuit.Elements.Impedance'>
#
# During handling of the above exception, another exception occurred:
#
# UnknownTranslator                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 schematic += Impedance(Z=30, name='Z3').down()
#       9 schematic += Line().left()
# ---> 10 schemdraw_solution = complex_solution(schematic)
#      11 schematic += schemdraw_solution.draw_voltage('Z1', precision=2)
#      12 schematic += schemdraw_solution.draw_current('Z1', precision=2)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramSolution.py:59, in complex_solution(schematic, solver, w, precision, polar, deg)
#      57 def complex_solution(schematic: elm.Schematic, solver: NetworkSolver = nodal_analysis_solver, w: float = 0, precision: int = 3, polar: bool = False, deg: bool = False) -> SchematicDiagramSolution:
#      58     digagram_parser = SchematicDiagramParser(schematic)
# ---> 59     solution = ComplexSolution(circuit=circuit_translator(schematic), solver=solver, w=w)
#      60     return SchematicDiagramSolution(
#      61         diagram_parser=digagram_parser,
#      62         solution=solution,
#    (...)
#      65         power_display=partial(dsp.print_complex, unit='VA', precision=precision, polar=polar, deg=deg)
#      66     )
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramTranslator.py:13, in circuit_translator(schematic)
#      11 def circuit_translator(schematic: elm.Schematic) -> Circuit:
#      12     schematic_diagram = SchematicDiagramParser(schematic)
# ---> 13     return schematic_diagram.translate_elements(circuit_translator_map)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramParser.py:100, in SchematicDiagramParser.translate_elements(self, translator_map)
#      98     except KeyError:
#      99         raise UnknownTranslator(f"Network element '{type(element).__name__}' cannot be translated.")
# --> 100 return circuit.Circuit([translate(e) for e in self.all_elements if translate(e) is not None])
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramParser.py:100, in <listcomp>(.0)
#      98     except KeyError:
#      99         raise UnknownTranslator(f"Network element '{type(element).__name__}' cannot be translated.")
# --> 100 return circuit.Circuit([translate(e) for e in self.all_elements if translate(e) is not None])
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramParser.py:99, in SchematicDiagramParser.translate_elements.<locals>.translate(element)
#      97     return translator_map[type(element)](element, tuple(map(self._get_node_index, elm.get_nodes(element))))
#      98 except KeyError:
# ---> 99     raise UnknownTranslator(f"Network element '{type(element).__name__}' cannot be translated.")
#
# UnknownTranslator: Network element 'Impedance' cannot be translated.
