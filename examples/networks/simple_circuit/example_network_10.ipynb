# %% [markdown]
# # Example 10

# %%
from CircuitCalculator.SimpleCircuit.Elements import Schematic, VoltageSource, Resistor, Line, LabelNode, CurrentSource, Ground
from CircuitCalculator.SimpleCircuit.DiagramSolution import real_network_dc_solution

# %%
R1, R2, R3, R4, R5 = 10, 20, 30, 40, 50
Uq1, Uq2, Iq1 = 1, 2, 0.1

unit = 8
with Schematic(unit=unit) as schematic:
    schematic += (N0 := Ground())
    schematic += VoltageSource(V=Uq1, name='Uq1', reverse=True, precision=1).up().length(2*unit)
    schematic += (N1 := LabelNode(id='1', id_loc='N'))
    schematic += Line().right()
    schematic += Line().up().length(unit/2)
    schematic += VoltageSource(V=Uq2, name='Uq2', reverse=True, precision=1).right()
    schematic += Line().down().length(unit/2)
    schematic += (N2 := LabelNode(id='2', id_loc='SE'))
    schematic += Resistor(R=R2, name='R2').left()
    schematic += Resistor(R=R1, name='R1').down().length(2*unit)
    schematic += Resistor(R=R3, name='R3').right()
    schematic += CurrentSource(I=Iq1, name='Iq1', precision=1).up()
    schematic += Resistor(R=R4, name='R4').up()
    schematic += Line().right()
    schematic += Resistor(R=R5, name='R5').down().length(2*unit)
    schematic += Line().left()
    schematic += Line().at(N0.start).right()
    schemdraw_solution = real_network_dc_solution(schematic)
    schematic += schemdraw_solution.draw_voltage('R1')
    schematic += schemdraw_solution.draw_voltage('R2')
    schematic += schemdraw_solution.draw_voltage('R3')
    schematic += schemdraw_solution.draw_voltage('R4')
    schematic += schemdraw_solution.draw_voltage('R5')
    schematic += schemdraw_solution.draw_voltage('Iq1')
    schematic += schemdraw_solution.draw_current('R1')
    schematic += schemdraw_solution.draw_current('R2')
    schematic += schemdraw_solution.draw_current('R3')
    schematic += schemdraw_solution.draw_current('R4')
    schematic += schemdraw_solution.draw_current('R5')
    schematic += schemdraw_solution.draw_current('Uq1')
    schematic += schemdraw_solution.draw_current('Uq2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 35
#      33 schematic += schemdraw_solution.draw_current('R4')
#      34 schematic += schemdraw_solution.draw_current('R5')
# ---> 35 schematic += schemdraw_solution.draw_current('Uq1')
#      36 schematic += schemdraw_solution.draw_current('Uq2')
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleCircuit/DiagramSolution.py:34, in SchematicDiagramSolution.draw_current(self, name, reverse, end)
#      32 def draw_current(self, name: str, reverse: bool = False, end: bool = False) -> elm.CurrentLabel:
#      33     element = self.diagram_parser.get_element(name)
# ---> 34     I_branch = self.solution.get_current(name)
#      35     if reverse:
#      36         I_branch *= -1
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Circuit/solution.py:54, in ComplexSolution.get_current(self, component_id)
#      53 def get_current(self, component_id: str) -> complex:
# ---> 54     return self._solution.get_current(component_id)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:145, in NodalAnalysisSolution.get_current(self, branch_id)
#     143     return branch.element.I
#     144 if is_ideal_voltage_source(branch.element):
# --> 145     Z = element_impedance(self._network, branch_id)
#     146     I_branch_element = -branch.element.V/Z
#     147     I_other_elements = short_circuit_current(
#     148         trf.remove_element(self._network, branch_id),
#     149         branch.node1,
#     150         branch.node2)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:74, in element_impedance(network, element, node_index_mapper)
#      73 def element_impedance(network: Network, element: str, node_index_mapper: map.NodeIndexMapper = map.default) -> complex:
# ---> 74     return open_circuit_impedance(
#      75         network=trf.remove_element(network, element),
#      76         node1=network[element].node1,
#      77         node2=network[element].node2,
#      78         node_index_mapper=node_index_mapper
#      79     )
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:70, in open_circuit_impedance(network, node1, node2, node_index_mapper)
#      68 Y = create_node_matrix_from_network(network, node_index_mapper=node_index_mapper)
#      69 Z = np.linalg.inv(Y)
# ---> 70 i1 = node_index_mapper(network)[node1]
#      71 return Z[i1][i1]
#
# KeyError: '1'
