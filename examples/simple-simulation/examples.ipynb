# %%
from CircuitCalculator.SimpleCircuit.styles.styling import select
select(style='DIN')
from CircuitCalculator.SimpleSimulation.simulator import show_schematic_from_file, simulate_schematic_from_file

# %%
show_schematic_from_file('current_dividor.json')
solution = simulate_schematic_from_file('current_dividor.json', 'dc', x=23)
print(f'V(R)={solution.get_voltage("R")}')
# Out:
# Simulation file "current_dvidor.json" does not exist.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 show_schematic_from_file('current_dvidor.json')
#       2 solution = simulate_schematic_from_file('current_dividor.json', 'dc', x=23)
#       3 print(f'V(R)={solution.get_voltage("R")}')
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleSimulation/simulator.py:34, in show_schematic_from_file(name, ax)
#      32 def show_schematic_from_file(name: str, ax: Optional[Axes] = None) -> None:
#      33     data = load_simulation_file(name)
# ---> 34     show_schematic(data, ax)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleSimulation/simulator.py:27, in show_schematic(data, ax)
#      25 def show_schematic(data: dict, ax: Optional[Axes] = None) -> None:
#      26     try:
# ...

# %%
show_schematic_from_file('voltage_dividor.yaml')

# %%
show_schematic_from_file('two_sources.yaml')

# %%
show_schematic_from_file('lamps.yaml')

# %%
show_schematic_from_file('reverse_voltage_source.yaml')

# %%
show_schematic_from_file('reverse_current_source.yaml')
