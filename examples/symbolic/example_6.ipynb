# %% [markdown]
# # Example 6 - Simple Simulation Approach

# %%
from CircuitCalculator.SimpleCircuit.styles.styling import select
select(style='DIN')
from CircuitCalculator.SimpleSimulation.simulator import show_schematic_from_file, simulate_schematic_from_file
import sympy as sp

# %%
show_schematic_from_file('voltage_dividor.yaml')

# %%
solution = simulate_schematic_from_file('voltage_dividor.yaml', 'symbolic')

V4 = sp.simplify(solution.get_voltage('R4'))
sp.pprint(V4)
# Out:
#                R₂⋅R₄⋅U₁
# ─────────────────────────────────────
# R₁⋅R₂ + R₁⋅R₃ + R₁⋅R₄ + R₂⋅R₃ + R₂⋅R₄
