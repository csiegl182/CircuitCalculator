# %% [markdown]
# # Example 5 - Frequency-Domain Analysis

# %%
from CircuitCalculator.Circuit.solution import ComplexSolution, TimeDomainSolution, FrequencyDomainSolution
from CircuitCalculator.SimpleAnalysis.PointerDiagram import voltage_pointer_diagram_analysis, current_pointer_diagram_analysis, power_pointer_diagram_analysis, plot_pointer_by_id
from CircuitCalculator.SimpleAnalysis.TimeSeries import steady_state_voltage_timedomain_analysis, steady_state_current_timedomain_analysis, plot_timeseries_by_id
from CircuitCalculator.SimpleAnalysis.FrequencyDomain import discrete_frequencies_voltage_analysis, discrete_frequencies_current_analysis, discrete_frequencies_power_analysis, plot_frequencies_by_id
from CircuitCalculator.SimpleAnalysis.NyquistDiagram import nyquist_voltage_analysis, plot_nyquist_by_id
from CircuitCalculator.SimpleCircuit.Elements import Schematic, Resistor, Line, Ground, RectVoltageSource, Capacitor
from CircuitCalculator.SimpleCircuit.DiagramTranslator import circuit_translator

# %%
with Schematic(unit=5) as schematic:
    schematic += RectVoltageSource(V=1, name='Uq', reverse=True, w=5000, phi=0)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
complex_solution = ComplexSolution(circuit, w=5000)
time_domain_solution = TimeDomainSolution(circuit, w_max=1000000)
frequency_domain_solution = FrequencyDomainSolution(circuit, w_max=50000)

# %%
_ = voltage_pointer_diagram_analysis(
    plot_pointer_by_id('Uq', color='blue'),
    plot_pointer_by_id('C', color='green'),
    plot_pointer_by_id('R', origin='C', color='red'),
    solution=complex_solution,
    pd_lim=(-1, 1, -1.5, 0.5)
)

# %%
_ = voltage_pointer_diagram_analysis(
    plot_pointer_by_id('C', color='green'),
    solution=complex_solution,
    layout_fcn=lambda : current_pointer_diagram_analysis(
        plot_pointer_by_id('C', scaling=1.5, color='red', label='I(C)'),
        solution=complex_solution
    )
)

# %%
_ = power_pointer_diagram_analysis(
    plot_pointer_by_id('Uq', color='blue'),
    plot_pointer_by_id('C', color='green', origin='Uq'),
    plot_pointer_by_id('R', color='red'),
    solution=complex_solution,
    pd_lim=(-0.5, 0.5, -0.5, 0.5)
)

# %%
_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Uq'),
    plot_timeseries_by_id('C', color='green'),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
_ = steady_state_current_timedomain_analysis(
    plot_timeseries_by_id('C', color='red'),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
_ = discrete_frequencies_voltage_analysis(
    plot_frequencies_by_id('Uq', lw=3),
    plot_frequencies_by_id('C', color='red'),
    solution=frequency_domain_solution,
    wmax=50000,
)

# %%
_ = discrete_frequencies_current_analysis(
    plot_frequencies_by_id('C', color='red'),
    plot_frequencies_by_id('Uq', color='blue'),
    solution=frequency_domain_solution,
    wmax=50000,
)
# Out:
# ---------------------------------------------------------------------------
# FloatingGroundNode                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 _ = discrete_frequencies_current_analysis(
#       2     plot_frequencies_by_id('C', color='red'),
#       3     plot_frequencies_by_id('Uq', color='blue'),
#       4     solution=frequency_domain_solution,
#       5     wmax=50000,
#       6 )
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/FrequencyDomain.py:92, in discrete_frequencies_current_analysis(layout_fcn, *args, **kwargs)
#      90 def discrete_frequencies_current_analysis(*args, layout_fcn:layout.Layout=layout.figure_two_rows, **kwargs) -> layout.FigureAxes:
#      91     plot_frequencydomain = plot_frequencydomain_factory(*args, type='current', **kwargs)
# ---> 92     return plot_frequencydomain(*layout_fcn())
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:47, in legend.<locals>.decorator.<locals>.wrapper(fig, ax, *args, **kwargs)
#      46 def wrapper(fig: Figure, ax: Axes, *args, **kwargs) -> FigureAxes:
# ---> 47     fig, ax = plot_fcn(fig, ax, *args, **kwargs)
#      48     ax[0].legend(
#      49         handles=[line for line in ax[0].lines if not line._label.startswith('_')],
#      50         ncol=len(ax[0].lines),
#    (...)
#      53         frameon=False
#      54     )
#      55     return fig, ax
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:64, in grid.<locals>.decorator.<locals>.wrapper(fig, ax, *args, **kwargs)
#      62 for a in ax:
#      63     a.grid(visible=visible, zorder=-1)
# ---> 64 return plot_fcn(fig, ax, *args, **kwargs)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:90, in xlabel_bottom.<locals>.decorator.<locals>.wrapper(fig, ax, *args, **kwargs)
#      88 def wrapper(fig: Figure, ax: Axes, *args, **kwargs) -> FigureAxes:
#      89     ax[-1].set_xlabel(label)
# ---> 90     return plot_fcn(fig, ax, *args, **kwargs)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:82, in xlim_bottom.<locals>.decorator.<locals>.wrapper(fig, ax, *args, **kwargs)
#      80 if xmax >= xmin:
#      81     ax[-1].set_xlim(left=xmin, right=xmax)
# ---> 82 return plot_fcn(fig, ax, *args, **kwargs)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:125, in bode_like_plot.<locals>.decorator.<locals>.wrapper(fig, ax, *args, **kwargs)
#     123 ax[-2].set_yscale('log' if logy else 'linear')
#     124 ax[-1].set_xscale('log' if logw else 'linear')
# --> 125 return plot_fcn(fig, ax, *args, **kwargs)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/FrequencyDomain.py:78, in plot_frequencydomain_factory.<locals>.plot_frequencydomain(fig, ax)
#      76 ax[-1].set_ylim(bottom=phi_min, top=phi_max)
#      77 new_args = [functools.partial(a, fd_fcn=fd_properties['fd_fcn'], label_fcn=fd_properties['label_fcn']) for a in args]
# ---> 78 layout.apply_plt_fcn(fig, ax, *new_args)
#      79 return fig, ax
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/layout.py:41, in apply_plt_fcn(fig, ax, *args)
#      39 def apply_plt_fcn(fig, ax, *args: PlotFcn) -> FigureAxes:
#      40     for plt_fcn in args:
# ---> 41         plt_fcn(fig, ax)
#      42     return fig, ax
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/SimpleAnalysis/FrequencyDomain.py:25, in plot_frequencies_by_id.<locals>.plot_frequencies(fig, ax, fd_fcn, label_fcn, **_)
#      23 if 'label' not in kwargs.keys():
#      24     kwargs.update({'label':label_fcn(id)})
# ---> 25 w, X = fd_fcn(id)
#      26 plot_discrete_frequencies_fcn(ax[-2], w, np.abs(X), **kwargs)
#      27 plot_discrete_frequencies_fcn(ax[-1], w, np.angle(X), **kwargs)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Circuit/solution.py:110, in FrequencyDomainSolution.get_current(self, component_id)
#     109 def get_current(self, component_id: str) -> FrequencyDomainFunction:
# --> 110     currents = np.array([solution.get_current(component_id) for solution in self._solutions])
#     111     return np.array(self.w), currents
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Circuit/solution.py:110, in <listcomp>(.0)
#     109 def get_current(self, component_id: str) -> FrequencyDomainFunction:
# --> 110     currents = np.array([solution.get_current(component_id) for solution in self._solutions])
#     111     return np.array(self.w), currents
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:147, in NodalAnalysisSolution.get_current(self, branch_id)
#     145     return branch.element.I
#     146 if is_ideal_voltage_source(branch.element):
# --> 147     Z = element_impedance(self._network, branch_id)
#     148     I_branch_element = -branch.element.V/Z
#     149     I_other_elements = short_circuit_current(
#     150         trf.remove_element(self._network, branch_id),
#     151         branch.node1,
#     152         branch.node2)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:74, in element_impedance(network, element, node_index_mapper)
#      73 def element_impedance(network: Network, element: str, node_index_mapper: map.NodeIndexMapper = map.default) -> complex:
# ---> 74     return open_circuit_impedance(
#      75         network=trf.remove_element(network, element),
#      76         node1=network[element].node1,
#      77         node2=network[element].node2,
#      78         node_index_mapper=node_index_mapper
#      79     )
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/NodalAnalysis.py:67, in open_circuit_impedance(network, node1, node2, node_index_mapper)
#      65     node1, node2 = node2, node1
#      66 network = trf.switch_ground_node(network=network, new_ground=node2)
# ---> 67 network = trf.passive_network(network)
#      68 Y = create_node_matrix_from_network(network, node_index_mapper=node_index_mapper)
#      69 Z = np.linalg.inv(Y)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/transformers.py:62, in passive_network(network, keep)
#      61 def passive_network(network: Network, keep: list[NortenTheveninElement] = []) -> Network:
# ---> 62     return remove_ideal_voltage_sources(remove_ideal_current_sources(network, keep=keep), keep=keep)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/transformers.py:56, in remove_ideal_current_sources(network, keep)
#      55 def remove_ideal_current_sources(network: Network, keep: list[NortenTheveninElement] = []) -> Network:
# ---> 56     return remove_open_circuit_elements(open_circuitify_current_sources(network, keep=keep))
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/transformers.py:14, in remove_open_circuit_elements(network)
#      13 def remove_open_circuit_elements(network: Network) -> Network:
# ---> 14     return Network([b for b in network.branches if not is_open_circuit(b.element)], node_zero_label=network.node_zero_label)
#
# File <string>:5, in __init__(self, branches, node_zero_label)
#
# File ~/Workspace/CircuitCalculator/src/CircuitCalculator/Network/network.py:25, in Network.__post_init__(self)
#      23 def __post_init__(self):
#      24     if self.node_zero_label not in self.node_labels and self.number_of_nodes != 0:
# ---> 25         raise FloatingGroundNode
#      26     if len(set(self.branch_ids)) != len(self.branches):
#      27         raise AmbiguousBranchIDs
#
# FloatingGroundNode:

# %%
_ = discrete_frequencies_power_analysis(
    plot_frequencies_by_id('Uq', color='blue'),
    solution=frequency_domain_solution,
    wmin=4000,
    wmax=50000,
    abs_min=0.001,
    logw=True,
    logy=True
)

# %%
_ = nyquist_voltage_analysis(
    plot_nyquist_by_id('C'),
    plot_nyquist_by_id('R'),
    solution=frequency_domain_solution,
    ax_lim=(-1, 1, -1, 1)
)
