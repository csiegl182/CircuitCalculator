# %% [markdown]
# # Example 11 - Comparision of Periodic Sources

# %%
from CircuitCalculator.Circuit.solution import TimeDomainSolution, FrequencyDomainSolution, ComplexSolution
from CircuitCalculator.SimpleAnalysis.TimeSeries import steady_state_voltage_timedomain_analysis, steady_state_current_timedomain_analysis, plot_timeseries_by_id
from CircuitCalculator.SimpleAnalysis.PointerDiagram import voltage_pointer_diagram_analysis, current_pointer_diagram_analysis, power_pointer_diagram_analysis, plot_pointer_by_id
from CircuitCalculator.SimpleAnalysis.NyquistDiagram import nyquist_voltage_analysis, plot_nyquist_by_id
from CircuitCalculator.SimpleCircuit.Elements import Schematic, Resistor, Line, Ground, RectVoltageSource, Capacitor, TriangleVoltageSource, SawtoothVoltageSource, VoltageSource, ACVoltageSource
from CircuitCalculator.SimpleAnalysis.FrequencyDomain import discrete_frequencies_voltage_analysis, discrete_frequencies_current_analysis, discrete_frequencies_power_analysis, plot_frequencies_by_id
from CircuitCalculator.SimpleCircuit.DiagramTranslator import circuit_translator

# %%
with Schematic(unit=3) as schematic:
    # schematic += RectVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    # schematic += TriangleVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    # schematic += SawtoothVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += VoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
time_domain_solution = TimeDomainSolution(circuit, w_max=1000000)

_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Vq', lw=2),
    plot_timeseries_by_id('C', color='red', ls='--', lw=2),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
with Schematic(unit=3) as schematic:
    # schematic += RectVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    # schematic += TriangleVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    # schematic += SawtoothVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += ACVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0, sin=False)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
time_domain_solution = TimeDomainSolution(circuit, w_max=1000000)

_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Vq', lw=2),
    plot_timeseries_by_id('C', color='red', ls='--', lw=2),
    plot_timeseries_by_id('R', color='green', ls='--', lw=2),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
with Schematic(unit=3) as schematic:
    schematic += RectVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
time_domain_solution = TimeDomainSolution(circuit, w_max=100*5000)

_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Vq', lw=2),
    plot_timeseries_by_id('C', color='red', ls='--', lw=2),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
with Schematic(unit=3) as schematic:
    schematic += TriangleVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
time_domain_solution = TimeDomainSolution(circuit, w_max=100*5000)

_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Vq', lw=2),
    plot_timeseries_by_id('C', color='red', ls='--', lw=2),
    solution=time_domain_solution,
    tmax=0.005
)

# %%
with Schematic(unit=3) as schematic:
    schematic += SawtoothVoltageSource(V=1, name='Vq', reverse=True, w=5000, phi=0)
    schematic += Resistor(R=2, name='R').right()
    schematic += Capacitor(C=1e-4, name='C').down()
    schematic += Line().left()
    schematic += Ground()
circuit = circuit_translator(schematic)
time_domain_solution = TimeDomainSolution(circuit, w_max=100*5000)

_ = steady_state_voltage_timedomain_analysis(
    plot_timeseries_by_id('Vq', lw=2),
    plot_timeseries_by_id('C', color='red', ls='--', lw=2),
    solution=time_domain_solution,
    tmax=0.005
)
